# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('versao1.csv', sep = ';', error_bad_lines=False)
# Out:
# b'Skipping line 27: expected 3 fields, saw 4\nSkipping line 41: expected 3 fields, saw 4\nSkipping line 72: expected 3 fields, saw 4\nSkipping line 73: expected 3 fields, saw 4\nSkipping line 75: expected 3 fields, saw 4\nSkipping line 76: expected 3 fields, saw 4\nSkipping line 97: expected 3 fields, saw 4\nSkipping line 120: expected 3 fields, saw 4\nSkipping line 122: expected 3 fields, saw 4\nSkipping line 310: expected 3 fields, saw 4\nSkipping line 312: expected 3 fields, saw 4\nSkipping line 335: expected 3 fields, saw 4\nSkipping line 340: expected 3 fields, saw 4\nSkipping line 442: expected 3 fields, saw 4\nSkipping line 486: expected 3 fields, saw 4\nSkipping line 568: expected 3 fields, saw 4\nSkipping line 630: expected 3 fields, saw 5\nSkipping line 633: expected 3 fields, saw 4\nSkipping line 697: expected 3 fields, saw 4\nSkipping line 770: expected 3 fields, saw 4\nSkipping line 844: expected 3 fields, saw 4\nSkipping line 950: expected 3 fields, saw 4\nSkipping line
# ...

# %%
df.shape
# Out:
# (30408, 3)

# %%
df.to_excel("databaseglobo.xlsx")

# %% [markdown]
# Went to R, now back do Python
